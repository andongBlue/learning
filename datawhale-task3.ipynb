# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np

# Display and Plotting
import matplotlib.pylab as plt
import seaborn as sns

# %%
filename_ts = r'C:\Users\60547\Documents\py\python_lianxi\datasets\datawhile\data.csv'
df=pd.read_csv(filename_ts,encoding='gbk')
# print(df.columns)
df.head(5)
# Out:
#    unnamedid   custid      trade_no bank_card_no  low_volume_percent  \
# 0          5  2791858  2.018050e+31          卡号1                0.01
# 1         10   534047  2.018050e+31          卡号1                0.02
# 2         12  2849787  2.018050e+31          卡号1                0.04
# 3         13  1809708  2.018050e+31          卡号1                0.00
# 4         14  2499829  2.018050e+31          卡号1                0.01
#
#    middle_volume_percent  take_amount_in_later_12_month_highest  \
# 0                   0.99                                      0
# 1                   0.94                                   2000
# 2                   0.96                                      0
# 3                   0.96                                   2000
# 4                   0.99                                      0
#
#    trans_amount_increase_rate_lately  trans_activity_month  \
# 0                               0.90                  0.55
# 1                               1.28                  1.00
# 2                               1.00                  1.00
# 3                               0.13                  0.57
# 4                               0.46                  1.00
#
#    trans_activity_day        ...         loans_max_limit  loans_avg_limit  \
# 0               0.313        ...                  2900.0           1688.0
# 1               0.458        ...                  3500.0           1758.0
# 2               0.114        ...                  1600.0           1250.0
# 3               0.777        ...                  3200.0           1541.0
# 4               0.175        ...                  2300.0           1630.0
#
#    consfin_credit_limit  consfin_credibility  consfin_org_count_current  \
# 0                1200.0                 75.0                        1.0
# 1               15100.0                 80.0                        5.0
# 2                4200.0                 87.0                        1.0
# 3               16300.0                 80.0                        5.0
# 4                8300.0                 79.0                        2.0
#
#    consfin_product_count  consfin_max_limit  consfin_avg_limit  \
# 0                    2.0             1200.0             1200.0
# 1                    6.0            22800.0             9360.0
# 2                    1.0             4200.0             4200.0
# 3                    5.0            30000.0            12180.0
# 4                    2.0             8400.0             8250.0
#
#    latest_query_day  loans_latest_day
# 0              12.0              18.0
# 1               4.0               2.0
# 2               2.0               6.0
# 3               2.0               4.0
# 4              22.0             120.0
#
# [5 rows x 90 columns]

# %%
#查看object类型的数据  值的分布
print(df.bank_card_no.value_counts(),'\n')
print(df.reg_preference_for_trad.value_counts(),'\n')
print(df.source.value_counts(),'\n')
print(df.student_feature.value_counts())
df.select_dtypes(include=['object']).head(5)
# Out:
# 卡号1    4754
# Name: bank_card_no, dtype: int64
#
# 一线城市    3403
# 三线城市    1064
# 境外       150
# 二线城市     131
# 其他城市       4
# Name: reg_preference_for_trad, dtype: int64
#
# xs    4754
# Name: source, dtype: int64
#
# 1.0    1754
# 2.0       2
# Name: student_feature, dtype: int64
#   bank_card_no reg_preference_for_trad source id_name latest_query_time  \
# 0          卡号1                    一线城市     xs      蒋红         2018/4/25
# 1          卡号1                    一线城市     xs     崔向朝          2018/5/3
# 2          卡号1                    一线城市     xs     王中云          2018/5/5
# 3          卡号1                    三线城市     xs     何洋洋          2018/5/5
# 4          卡号1                    一线城市     xs      赵洋         2018/4/15
#
#   loans_latest_time
# 0         2018/4/19
# 1          2018/5/5
# 2          2018/5/1
# 3          2018/5/3
# 4          2018/1/7

# %%
#查看标签列 status的分布均衡性(处理前)
print(df['status'].value_counts())
df['status'].value_counts().plot(kind='bar')
# Out:
# 0    3561
# 1    1193
# Name: status, dtype: int64

# %%
#student_feature缺失太多直接丢弃,其他没有业务价值
drop_columns=['bank_card_no','source','id_name','unnamedid','custid','student_feature','trade_no']
df.drop(drop_columns,axis=1,inplace=True)

#日期处理为日期格式datetime，并生成新的一列 loans_time
df['latest_query_time']=pd.to_datetime(df['latest_query_time'])
df['loans_latest_time']=pd.to_datetime(df['loans_latest_time'])

#将timedelta格式转化为float类型(秒)
df['loans_time']=df['loans_latest_time']-df['latest_query_time']
df['loans_time']=df['loans_time'].dt.total_seconds().dropna()

#两列日期格式数据处理直接丢弃
datatime_data=['loans_latest_time','latest_query_time']
df.drop(datatime_data,axis=1,inplace=True)

#将城市进行数值化
map_dict={'一线城市':1,'二线城市':2,'三线城市':3,'境外':4,'其他':0}
df['reg_preference_for_trad']=df['reg_preference_for_trad'].map(map_dict)
df.head()
# Out:
#    low_volume_percent  middle_volume_percent  \
# 0                0.01                   0.99
# 1                0.02                   0.94
# 2                0.04                   0.96
# 3                0.00                   0.96
# 4                0.01                   0.99
#
#    take_amount_in_later_12_month_highest  trans_amount_increase_rate_lately  \
# 0                                      0                               0.90
# 1                                   2000                               1.28
# 2                                      0                               1.00
# 3                                   2000                               0.13
# 4                                      0                               0.46
#
#    trans_activity_month  trans_activity_day  transd_mcc  \
# 0                  0.55               0.313        17.0
# 1                  1.00               0.458        19.0
# 2                  1.00               0.114        13.0
# 3                  0.57               0.777        22.0
# 4                  1.00               0.175        13.0
#
#    trans_days_interval_filter  trans_days_interval  regional_mobility  \
# 0                        27.0                 26.0                3.0
# 1                        30.0                 14.0                4.0
# 2                        68.0                 22.0                1.0
# 3                        14.0                  6.0                3.0
# 4                        66.0                 42.0                1.0
#
#       ...      loans_avg_limit  consfin_credit_limit  consfin_credibility  \
# 0     ...               1688.0                1200.0                 75.0
# 1     ...               1758.0               15100.0                 80.0
# 2     ...               1250.0                4200.0                 87.0
# 3     ...               1541.0               16300.0                 80.0
# 4     ...               1630.0                8300.0                 79.0
#
#    consfin_org_count_current  consfin_product_count  consfin_max_limit  \
# 0                        1.0                    2.0             1200.0
# 1                        5.0                    6.0            22800.0
# 2                        1.0                    1.0             4200.0
# 3                        5.0                    5.0            30000.0
# 4                        2.0                    2.0             8400.0
#
#    consfin_avg_limit  latest_query_day  loans_latest_day  loans_time
# 0             1200.0              12.0              18.0   -518400.0
# 1             9360.0               4.0               2.0    172800.0
# 2             4200.0               2.0               6.0   -345600.0
# 3            12180.0               2.0               4.0   -172800.0
# 4             8250.0              22.0             120.0  -8467200.0
#
# [5 rows x 82 columns]

# %%
#统计缺失值
print('缺失值:','\n',df.isnull().sum())
# Out:
# 缺失值:
#  low_volume_percent                          2
# middle_volume_percent                       2
# take_amount_in_later_12_month_highest       0
# trans_amount_increase_rate_lately           3
# trans_activity_month                        2
# trans_activity_day                          2
# transd_mcc                                  2
# trans_days_interval_filter                  8
# trans_days_interval                         2
# regional_mobility                           2
# repayment_capability                        0
# is_high_user                                0
# number_of_trans_from_2011                   2
# first_transaction_time                      2
# historical_trans_amount                     0
# historical_trans_day                        2
# rank_trad_1_month                           2
# trans_amount_3_month                        0
# avg_consume_less_12_valid_month             2
# abs                                         0
# top_trans_count_last_1_month                2
# avg_price_last_12_month                     0
# avg_price_top_last_12_valid_month         104
# reg_preference_for_trad                     6
# trans_top_time_last_1_month                 8
# trans_top_time_last_6_month                 8
# consume_top_time_last_1_month               8
# consume_top_time_last_6_month               8
# cross_consume_count_last_1_month          426
# trans_fail_top_count_enum_last_1_month     16
#                                          ...
# loans_credibility_behavior                297
# loans_count                               297
# loans_settle_count                        297
# loans_overdue_count                       297
# loans_org_count_behavior                  297
# consfin_org_count_behavior                297
# loans_cash_count                          297
# latest_one_month_loan                     297
# latest_three_month_loan                   297
# latest_six_month_loan                     297
# history_suc_fee                           297
# history_fail_fee                          297
# latest_one_month_suc                      297
# latest_one_month_fail                     297
# loans_long_time                           297
# loans_credit_limit                        297
# loans_credibility_limit                   297
# loans_org_count_current                   297
# loans_product_count                       297
# loans_max_limit                           297
# loans_avg_limit                           297
# consfin_credit_limit                      297
# consfin_credibility                       297
# consfin_org_count_current                 297
# consfin_product_count                     297
# consfin_max_limit                         297
# consfin_avg_limit                         297
# latest_query_day                          304
# loans_latest_day                          297
# loans_time                                323
# Length: 82, dtype: int64

# %%
#动作1：数量较小，直接丢弃
# df.dropna(inplace=True)

#动作2：缺失值以中位值进行填充
from sklearn.preprocessing import Imputer
columns=list(df)
imp=Imputer(missing_values=np.nan,strategy='median')
df=imp.fit_transform(df)
print('number after processing:',df.shape)
df=pd.DataFrame(df,columns=columns)

#再次统计缺失值
print('缺失值:','\n',(df.isnull().sum()))
df.head()
# Out:
# number after processing: (4754, 82)
# 缺失值:
#  low_volume_percent                        0
# middle_volume_percent                     0
# take_amount_in_later_12_month_highest     0
# trans_amount_increase_rate_lately         0
# trans_activity_month                      0
# trans_activity_day                        0
# transd_mcc                                0
# trans_days_interval_filter                0
# trans_days_interval                       0
# regional_mobility                         0
# repayment_capability                      0
# is_high_user                              0
# number_of_trans_from_2011                 0
# first_transaction_time                    0
# historical_trans_amount                   0
# historical_trans_day                      0
# rank_trad_1_month                         0
# trans_amount_3_month                      0
# avg_consume_less_12_valid_month           0
# abs                                       0
# top_trans_count_last_1_month              0
# avg_price_last_12_month                   0
# avg_price_top_last_12_valid_month         0
# reg_preference_for_trad                   0
# trans_top_time_last_1_month               0
# trans_top_time_last_6_month               0
# consume_top_time_last_1_month             0
# consume_top_time_last_6_month             0
# cross_consume_count_last_1_month          0
# trans_fail_top_count_enum_last_1_month    0
#                                          ..
# loans_credibility_behavior                0
# loans_count                               0
# loans_settle_count                        0
# loans_overdue_count                       0
# loans_org_count_behavior                  0
# consfin_org_count_behavior                0
# loans_cash_count                          0
# latest_one_month_loan                     0
# latest_three_month_loan                   0
# latest_six_month_loan                     0
# history_suc_fee                           0
# history_fail_fee                          0
# latest_one_month_suc                      0
# latest_one_month_fail                     0
# loans_long_time                           0
# loans_credit_limit                        0
# loans_credibility_limit                   0
# loans_org_count_current                   0
# loans_product_count                       0
# loans_max_limit                           0
# loans_avg_limit                           0
# consfin_credit_limit                      0
# consfin_credibility                       0
# consfin_org_count_current                 0
# consfin_product_count                     0
# consfin_max_limit                         0
# consfin_avg_limit                         0
# latest_query_day                          0
# loans_latest_day                          0
# loans_time                                0
# Length: 82, dtype: int64
#    low_volume_percent  middle_volume_percent  \
# 0                0.01                   0.99
# 1                0.02                   0.94
# 2                0.04                   0.96
# 3                0.00                   0.96
# 4                0.01                   0.99
#
#    take_amount_in_later_12_month_highest  trans_amount_increase_rate_lately  \
# 0                                    0.0                               0.90
# 1                                 2000.0                               1.28
# 2                                    0.0                               1.00
# 3                                 2000.0                               0.13
# 4                                    0.0                               0.46
#
#    trans_activity_month  trans_activity_day  transd_mcc  \
# 0                  0.55               0.313        17.0
# 1                  1.00               0.458        19.0
# 2                  1.00               0.114        13.0
# 3                  0.57               0.777        22.0
# 4                  1.00               0.175        13.0
#
#    trans_days_interval_filter  trans_days_interval  regional_mobility  \
# 0                        27.0                 26.0                3.0
# 1                        30.0                 14.0                4.0
# 2                        68.0                 22.0                1.0
# 3                        14.0                  6.0                3.0
# 4                        66.0                 42.0                1.0
#
#       ...      loans_avg_limit  consfin_credit_limit  consfin_credibility  \
# 0     ...               1688.0                1200.0                 75.0
# 1     ...               1758.0               15100.0                 80.0
# 2     ...               1250.0                4200.0                 87.0
# 3     ...               1541.0               16300.0                 80.0
# 4     ...               1630.0                8300.0                 79.0
#
#    consfin_org_count_current  consfin_product_count  consfin_max_limit  \
# 0                        1.0                    2.0             1200.0
# 1                        5.0                    6.0            22800.0
# 2                        1.0                    1.0             4200.0
# 3                        5.0                    5.0            30000.0
# 4                        2.0                    2.0             8400.0
#
#    consfin_avg_limit  latest_query_day  loans_latest_day  loans_time
# 0             1200.0              12.0              18.0   -518400.0
# 1             9360.0               4.0               2.0    172800.0
# 2             4200.0               2.0               6.0   -345600.0
# 3            12180.0               2.0               4.0   -172800.0
# 4             8250.0              22.0             120.0  -8467200.0
#
# [5 rows x 82 columns]

# %%
#丢掉方差为0即没有变化的列
df.drop(df.columns[df.std()==0],axis=1,inplace=True)
df.shape
# Out:
# (4754, 82)

# %%
#查看标签列 status的分布均衡性(处理后)
print(df['status'].value_counts())
df['status'].value_counts().plot(kind='bar')
# Out:
# 0.0    3561
# 1.0    1193
# Name: status, dtype: int64

# %%
#换种方式考察各列和目标列之间的相关性
# cor=df.corr()

# corr=np.abs(cor['status'].sort_values(ascending=False)).to_frame(name='corelation').reset_index()
# print(type(np.abs(cor['status'].sort_values(ascending=False))))
# #选取特征大于0.05的列进行保留
# deleted_corr_columns=list(corr[corr.corelation<0.05]['index'])
# print(deleted_corr_columns)
# df.drop(deleted_corr_columns,inplace=True,axis=1)
# corr

# %%
# #热力图研究相关性
# plt.figure(figsize=(54,46))
# corr=df.drop(['status'],axis=1).corr()
# #注意给lables值设置大小和格式,不然显示不清
# #show 列表名
# print(list(df))
# print(df.shape)
# sns.heatmap(corr,fmt='.2f',annot=True,cbar=False,annot_kws={'size':24,'weight':'bold'})

# %% [markdown]
# #将相关系数超过0.9的进行筛选，只保留一列

# %%
# further_drop=['trans_top_time_last_1_month','trans_fail_top_count_enum_last_12_month','apply_score','consfin_avg_limit']
# df.drop(further_drop,axis=1,inplace=True)

# %% [markdown]
# 以上暂不使用

# %%
train_x=df.drop(['status'],axis=1)
train_y=df['status']

print(train_x.shape)
train_x.head()
# Out:
# (4754, 81)
#    low_volume_percent  middle_volume_percent  \
# 0                0.01                   0.99
# 1                0.02                   0.94
# 2                0.04                   0.96
# 3                0.00                   0.96
# 4                0.01                   0.99
#
#    take_amount_in_later_12_month_highest  trans_amount_increase_rate_lately  \
# 0                                    0.0                               0.90
# 1                                 2000.0                               1.28
# 2                                    0.0                               1.00
# 3                                 2000.0                               0.13
# 4                                    0.0                               0.46
#
#    trans_activity_month  trans_activity_day  transd_mcc  \
# 0                  0.55               0.313        17.0
# 1                  1.00               0.458        19.0
# 2                  1.00               0.114        13.0
# 3                  0.57               0.777        22.0
# 4                  1.00               0.175        13.0
#
#    trans_days_interval_filter  trans_days_interval  regional_mobility  \
# 0                        27.0                 26.0                3.0
# 1                        30.0                 14.0                4.0
# 2                        68.0                 22.0                1.0
# 3                        14.0                  6.0                3.0
# 4                        66.0                 42.0                1.0
#
#       ...      loans_avg_limit  consfin_credit_limit  consfin_credibility  \
# 0     ...               1688.0                1200.0                 75.0
# 1     ...               1758.0               15100.0                 80.0
# 2     ...               1250.0                4200.0                 87.0
# 3     ...               1541.0               16300.0                 80.0
# 4     ...               1630.0                8300.0                 79.0
#
#    consfin_org_count_current  consfin_product_count  consfin_max_limit  \
# 0                        1.0                    2.0             1200.0
# 1                        5.0                    6.0            22800.0
# 2                        1.0                    1.0             4200.0
# 3                        5.0                    5.0            30000.0
# 4                        2.0                    2.0             8400.0
#
#    consfin_avg_limit  latest_query_day  loans_latest_day  loans_time
# 0             1200.0              12.0              18.0   -518400.0
# 1             9360.0               4.0               2.0    172800.0
# 2             4200.0               2.0               6.0   -345600.0
# 3            12180.0               2.0               4.0   -172800.0
# 4             8250.0              22.0             120.0  -8467200.0
#
# [5 rows x 81 columns]

# %%
#拆分测试集和训练集
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(train_x,train_y,test_size=0.3,random_state=2018)
print(x_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (3327, 81)
# (1427, 81)
# (1427,)

# %%
#引入模型进行训练
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
# Out:
# C:\Users\60547\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
#定义计算iv值的函数
def calc_iv(df, feature, target, pr=False):
    """
    Set pr=True to enable printing of output.

    Output:
      * iv: float,
      * data: pandas.DataFrame
    """
    lst = []
    df[feature] = df[feature].fillna('NULL')

    for i in range(df[feature].nunique()):  # nuinque()是查看该序列(axis=0/1对应着列或行)的不同值的数量个数
        val = list(df[feature].unique())[i]
        lst.append([feature,
                    val,  # Value
                    df[df[feature] == val].count()[feature],  # all
                    df[(df[feature] == val) & (df[target] == 0)].count()[feature],  # good rate
                    df[(df[feature] == val) & (df[target] == 1)].count()[feature]])  # bad rate
    data = pd.DataFrame(lst, columns=['Variable', 'Value', 'All', 'Good', 'Bad'])

    data['Share'] = data['All'] / data['All'].sum()
    data['Bad Rate'] = data['Bad'] / data['All']
    data['Distribution Good'] = (data['All'] - data['Bad']) / (data['All'].sum() - data['Bad'].sum())
    data['Distribution Bad'] = data['Bad'] / data['Bad'].sum()
    data['WoE'] = np.log(data['Distribution Good'] / data['Distribution Bad'])

    data = data.replace({'WoE': {np.inf: 0, -np.inf: 0}})

    data['IV'] = data['WoE'] * (data['Distribution Good'] - data['Distribution Bad'])

    data = data.sort_values(by=['Variable', 'Value'], ascending=[True, True])
    data.index = range(len(data.index))

    if pr:
        print(data)
        print("IV = ", data['IV'].sum())

    iv = data['IV'].sum()

    return iv, data

column_headers = list(df.columns.values)
# print(column_headers)

d=[]
for x in column_headers:
    IV_1, data = calc_iv(df, x, 'status')
    d.append(IV_1)
#整理成Series类型并合并
column_headers=pd.Series(column_headers,name='feature')
d=pd.Series(d,name='iv_value')

# print(column_headers)
iv_result=pd.concat([column_headers,d],axis=1)
iv_result.sort_values(by='iv_value',ascending=False)

#     print('{}： {}'.format(x, IV_1))
# Out:
#                                        feature  iv_value
# 51                                 loans_score  0.615595
# 29      trans_fail_top_count_enum_last_1_month  0.598137
# 63                            history_fail_fee  0.507044
# 42                                 apply_score  0.488201
# 40                       first_transaction_day  0.486122
# 13                      first_transaction_time  0.486122
# 10                        repayment_capability  0.439096
# 33        max_cumulative_consume_later_1_month  0.395649
# 55                         loans_overdue_count  0.387895
# 19                                         abs  0.372721
# 5                           trans_activity_day  0.364895
# 72                             loans_avg_limit  0.352420
# 15                        historical_trans_day  0.352322
# 37  pawns_auctions_trusts_consume_last_6_month  0.338961
# 3            trans_amount_increase_rate_lately  0.287298
# 30      trans_fail_top_count_enum_last_6_month  0.279096
# 78                           consfin_avg_limit  0.273307
# 31     trans_fail_top_count_enum_last_12_month  0.266281
# 65                       latest_one_month_fail  0.252393
# 17                        trans_amount_3_month  0.244848
# 81                                  loans_time  0.221253
# 73                        consfin_credit_limit  0.212635
# 21                     avg_price_last_12_month  0.199738
# 36  pawns_auctions_trusts_consume_last_1_month  0.196995
# 80                            loans_latest_day  0.176634
# 41                     trans_day_last_12_month  0.169691
# 64                        latest_one_month_suc  0.143365
# 79                            latest_query_day  0.141164
# 53                                 loans_count  0.136256
# 62                             history_suc_fee  0.129193
# ..                                         ...       ...
# 60                     latest_three_month_loan  0.044632
# 22           avg_price_top_last_12_valid_month  0.044629
# 43                           apply_credibility  0.040658
# 50                      latest_six_month_apply  0.039726
# 67                          loans_credit_limit  0.036173
# 6                                   transd_mcc  0.036095
# 0                           low_volume_percent  0.034352
# 56                    loans_org_count_behavior  0.032244
# 46                            query_cash_count  0.031778
# 70                         loans_product_count  0.029965
# 69                     loans_org_count_current  0.029706
# 58                            loans_cash_count  0.029706
# 34             max_consume_count_later_6_month  0.029597
# 74                         consfin_credibility  0.028089
# 44                             query_org_count  0.027715
# 76                       consfin_product_count  0.025657
# 57                  consfin_org_count_behavior  0.024340
# 75                   consfin_org_count_current  0.024340
# 68                     loans_credibility_limit  0.023560
# 45                         query_finance_count  0.018837
# 59                       latest_one_month_loan  0.015595
# 52                  loans_credibility_behavior  0.014812
# 18             avg_consume_less_12_valid_month  0.013734
# 28            cross_consume_count_last_1_month  0.013474
# 9                            regional_mobility  0.007948
# 35         railway_consume_count_last_12_month  0.005717
# 11                                is_high_user  0.005614
# 23                     reg_preference_for_trad  0.004833
# 38          jewelry_consume_count_last_6_month  0.001361
# 39                                      status  0.000000
#
# [82 rows x 2 columns]

# %% [markdown]
# 在机器学习的二分类问题中，IV值（Information Value）主要用来对输入变量进行编码和预测能力评估。特征变量IV值的大小即表示该变量预测能力的强弱。IV 值的取值范围是[0, 正无穷)，如果当前分组中只包含响应客户或者未响应客户时，IV = 正无穷。
# 量化指标含义如下：< 0.02useless for prediction、0.02 to 0.1Weak predictor、0.1 to 0.3Medium predictor、0.3 to 0.5Strong predictor 、>0.5 Suspicious or too good to be true。

# %%
#筛选IV值大于0.02的作为有效可预测列
iv_below=iv_result[iv_result['iv_value']<0.02]
deleted_cols_by_iv=list(iv_below.feature)
deleted_cols_by_iv.remove('status')

# %%
x_train.drop(deleted_cols_by_iv,axis=1,inplace=True)
x_test.drop(deleted_cols_by_iv,axis=1,inplace=True)

# %%
# 此时选择将x_train进行标准化
from sklearn.preprocessing import StandardScaler
columns=list(x_train)
x_train=StandardScaler().fit_transform(x_train)
x_train=pd.DataFrame(x_train,columns=columns)

x_test=StandardScaler().fit_transform(x_test)
x_test=pd.DataFrame(x_test,columns=columns)

# %%
#定义返回y_pred和y_pred_proba的函数，并能打印训练集和测试集的精度以及ROC曲线面积
def model_metrics(clf, X_train, X_test, y_train, y_test):
    clf.fit(X_train,y_train)
    # 预测
    y_train_pred = clf.predict(X_train)
    y_test_pred = clf.predict(X_test)
    
    y_train_proba = clf.predict_proba(X_train)[:,1]
    y_test_proba = clf.predict_proba(X_test)[:,1]
    
    # 准确率
    print('[准确率]', end = ' ')
    print('训练集：', '%.4f'%accuracy_score(y_train, y_train_pred), end = ' ')
    print('测试集：', '%.4f'%accuracy_score(y_test, y_test_pred))
    
#     auc取值：用roc_auc_score或auc
    print('[auc值]', end = ' ')
    print('训练集：', '%.4f'%roc_auc_score(y_train, y_train_proba), end = ' ')
    print('测试集：', '%.4f'%roc_auc_score(y_test, y_test_proba))
    
    #加上return方便后续计算混淆矩阵效果
    return y_test_proba,y_test_pred

# %%
#调入随机森林模型，无调参之前看下分数

rf=RandomForestClassifier()

model_metrics(rf,x_train,x_test,y_train,y_test)
# Out:
# [准确率] 训练集： 0.9841 测试集： 0.7498
# [auc值] 训练集： 0.9995 测试集： 0.6896
# (array([0.1, 0. , 0.5, ..., 0.3, 0.5, 0.2]),
#  array([0., 0., 0., ..., 0., 0., 0.]))

# %%
feature_importance=sorted(zip(rf.feature_importances_,list(x_train)),reverse=True)
print(len(feature_importance))
feature_importance
# Out:
# 71
# [(0.06757808594949573, 'history_fail_fee'),
#  (0.061256513835872106, 'trans_fail_top_count_enum_last_1_month'),
#  (0.03990042623949093, 'loans_score'),
#  (0.024839925922934707, 'apply_score'),
#  (0.024641063723277346, 'loans_overdue_count'),
#  (0.019687490211358315, 'trans_day_last_12_month'),
#  (0.018526850042562555, 'historical_trans_day'),
#  (0.01827152561573461, 'avg_price_last_12_month'),
#  (0.01797435985408617, 'trans_amount_3_month'),
#  (0.017360720184045338, 'consfin_avg_limit'),
#  (0.017244839057045425, 'trans_activity_day'),
#  (0.017163219368769297, 'trans_days_interval_filter'),
#  (0.016616124613748656, 'first_transaction_day'),
#  (0.01587243056309651, 'trans_amount_increase_rate_lately'),
#  (0.015737589819461738, 'abs'),
#  (0.01544479772718679, 'loans_time'),
#  (0.014596860415621114, 'repayment_capability'),
#  (0.014474136283481731, 'pawns_auctions_trusts_consume_last_6_month'),
#  (0.014310990125780191, 'max_cumulative_consume_later_1_month'),
#  (0.013945759439487223, 'latest_one_month_suc'),
#  (0.01363084671069587, 'latest_query_day'),
#  (0.013506971948351418, 'trans_fail_top_count_enum_last_6_month'),
#  (0.01348804605458806, 'trans_top_time_last_6_month'),
#  (0.01346750313771664, 'number_of_trans_from_2011'),
#  (0.013264382398178587, 'consfin_max_limit'),
#  (0.013172725037378052, 'first_transaction_time'),
#  (0.012982450975538587, 'historical_trans_amount'),
#  (0.012840683734844876, 'loans_avg_limit'),
#  (0.012830796833541786, 'loans_latest_day'),
#  (0.01267515688065384, 'query_cash_count'),
#  (0.012460117154788907, 'rank_trad_1_month'),
#  (0.012356368775330737, 'history_suc_fee'),
#  (0.012214302957950887, 'trans_days_interval'),
#  (0.01218282751577466, 'loans_long_time'),
#  (0.011835671550406194, 'latest_one_month_fail'),
#  (0.011830235770589469, 'latest_six_month_loan'),
#  (0.011755652030036636, 'trans_fail_top_count_enum_last_12_month'),
#  (0.011613723994881194, 'transd_mcc'),
#  (0.011154015648414131, 'trans_top_time_last_1_month'),
#  (0.01113456542045164, 'trans_activity_month'),
#  (0.010958526117540003, 'latest_six_month_apply'),
#  (0.010943095761155552, 'latest_one_month_apply'),
#  (0.01090724212707208, 'loans_settle_count'),
#  (0.010745744521383003, 'middle_volume_percent'),
#  (0.010743851574847717, 'consfin_credibility'),
#  (0.010704158509037671, 'apply_credibility'),
#  (0.010641618001818998, 'consume_mini_time_last_1_month'),
#  (0.010513368194229048, 'avg_price_top_last_12_valid_month'),
#  (0.010360308832043695, 'consume_top_time_last_1_month'),
#  (0.010164055861383825, 'consfin_credit_limit'),
#  (0.009702159002680424, 'max_consume_count_later_6_month'),
#  (0.00967905388795689, 'loans_org_count_current'),
#  (0.009585307502762859, 'pawns_auctions_trusts_consume_last_1_month'),
#  (0.009363569455646658, 'query_org_count'),
#  (0.009236940183983175, 'consfin_org_count_current'),
#  (0.00911407801870592, 'take_amount_in_later_12_month_highest'),
#  (0.00908856014925017, 'loans_org_count_behavior'),
#  (0.00894516493913044, 'loans_max_limit'),
#  (0.008933055390997842, 'query_sum_count'),
#  (0.00891400010149939, 'consfin_product_count'),
#  (0.008826536885595235, 'latest_three_month_apply'),
#  (0.008639800045550363, 'latest_three_month_loan'),
#  (0.008611927639162315, 'loans_cash_count'),
#  (0.008397802030469675, 'loans_credit_limit'),
#  (0.008256428073997766, 'consume_top_time_last_6_month'),
#  (0.008250859039645096, 'loans_count'),
#  (0.008246267799252341, 'loans_product_count'),
#  (0.007833270507933364, 'loans_credibility_limit'),
#  (0.006855795746411676, 'consfin_org_count_behavior'),
#  (0.005973011540212755, 'low_volume_percent'),
#  (0.005023689035995454, 'top_trans_count_last_1_month')]

# %%
x_train.head(2)
# Out:
#    low_volume_percent  middle_volume_percent  \
# 0           -0.291017               0.610479
# 1            0.191762               0.470992
#
#    take_amount_in_later_12_month_highest  trans_amount_increase_rate_lately  \
# 0                               0.499187                          -0.021817
# 1                              -0.351729                          -0.021926
#
#    trans_activity_month  trans_activity_day  transd_mcc  \
# 0              0.983413            0.238468   -0.322422
# 1              0.983413           -0.937386    0.123513
#
#    trans_days_interval_filter  trans_days_interval  repayment_capability  \
# 0                    0.001348             0.385087             -0.026841
# 1                   -0.088364             0.324197             -0.065450
#
#       ...      loans_avg_limit  consfin_credit_limit  consfin_credibility  \
# 0     ...             0.046929              0.214578             0.338205
# 1     ...            -0.031812              1.024701             0.116722
#
#    consfin_org_count_current  consfin_product_count  consfin_max_limit  \
# 0                   0.809769               0.551295          -0.024303
# 1                   0.114696              -0.057150           0.410648
#
#    consfin_avg_limit  latest_query_day  loans_latest_day  loans_time
# 0           0.054607         -0.646478         -0.867756    0.379832
# 1          -0.142723          0.183842         -0.523012    0.594848
#
# [2 rows x 71 columns]

# %%
#randomforest给出特征重要性排序,但具体取多少列无法定夺，使用for 循环迭代(前i列)其他为无用列，整体精度score作为指标,将其封装为函数
def select_feature_importance(feature_importance):
    score_list=[]
    for i in range(10,len(feature_importance)+1):
        useless=[]
        
        for feature in x_train.columns:
            if feature in [t[1] for t in feature_importance[i:]]:
                useless.append(feature)
        x_train.drop(useless,axis=1,inplace=True)
        x_test.drop(useless,axis=1,inplace=True)

        rf.fit(x_train,y_train)
    #将score装进容器
    
        score=rf.score(x_test,y_test)
        score_list.append(score)
        print('选择feature_importance前{}位,score is:'.format(i),score)
#     print('best score is',max(score_list),'selected cols=',score_list.index(max(score_list))+5)
    return max(score_list),(score_list.index(max(score_list))+5)
        
select_feature_importance(feature_importance)
# Out:
# 选择feature_importance前10位,score is: 0.7729502452697968
# 选择feature_importance前11位,score is: 0.7652417659425368
# 选择feature_importance前12位,score is: 0.7617379117028732
# 选择feature_importance前13位,score is: 0.7813594954449895
# 选择feature_importance前14位,score is: 0.7708479327259986
# 选择feature_importance前15位,score is: 0.7638402242466713
# 选择feature_importance前16位,score is: 0.7575332866152769
# 选择feature_importance前17位,score is: 0.7652417659425368
# 选择feature_importance前18位,score is: 0.764540995094604
# 选择feature_importance前19位,score is: 0.759635599159075
# 选择feature_importance前20位,score is: 0.7652417659425368
# 选择feature_importance前21位,score is: 0.7778556412053259
# 选择feature_importance前22位,score is: 0.7589348283111422
# 选择feature_importance前23位,score is: 0.7666433076384023
# 选择feature_importance前24位,score is: 0.7631394533987386
# 选择feature_importance前25位,score is: 0.7624386825508059
# 选择feature_importance前26位,score is: 0.7631394533987386
# 选择feature_importance前27位,score is: 0.764540995094604
# 选择feature_importance前28位,score is: 0.7715487035739313
# 选择feature_importance前29位,score is: 0.775052557813595
# 选择feature_importance前30位,score is: 0.7729502452697968
# 选择feature_importance前31位,score is: 0.7554309740714786
# 选择feature_importance前32位,score is: 0.7687456201822004
# 选择feature_importance前33位,score is: 0.7638402242466713
# 选择feature_importance前34位,score is: 0.7708479327259986
# 选择feature_importance前35位,score is: 0.7680448493342676
# 选择feature_importance前36位,score is: 0.7582340574632095
# 选择feature_importance前37位,score is: 0.7631394533987386
# 选择feature_importance前38位,score is: 0.7575332866152769
# 选择feature_importance前39位,score is: 0.7631394533987386
# 选择feature_importance前40位,score is: 0.7715487035739313
# 选择feature_importance前41位,score is: 0.7771548703573932
# 选择feature_importance前42位,score is: 0.7687456201822004
# 选择feature_importance前43位,score is: 0.7526278906797477
# 选择feature_importance前44位,score is: 0.7631394533987386
# 选择feature_importance前45位,score is: 0.7729502452697968
# 选择feature_importance前46位,score is: 0.7764540995094604
# 选择feature_importance前47位,score is: 0.7813594954449895
# 选择feature_importance前48位,score is: 0.767344078486335
# 选择feature_importance前49位,score is: 0.7736510161177295
# 选择feature_importance前50位,score is: 0.7533286615276804
# 选择feature_importance前51位,score is: 0.7554309740714786
# 选择feature_importance前52位,score is: 0.7575332866152769
# 选择feature_importance前53位,score is: 0.7680448493342676
# 选择feature_importance前54位,score is: 0.7680448493342676
# 选择feature_importance前55位,score is: 0.7680448493342676
# 选择feature_importance前56位,score is: 0.7680448493342676
# 选择feature_importance前57位,score is: 0.7589348283111422
# 选择feature_importance前58位,score is: 0.775052557813595
# 选择feature_importance前59位,score is: 0.7652417659425368
# 选择feature_importance前60位,score is: 0.7631394533987386
# 选择feature_importance前61位,score is: 0.7540294323756132
# 选择feature_importance前62位,score is: 0.759635599159075
# 选择feature_importance前63位,score is: 0.7652417659425368
# 选择feature_importance前64位,score is: 0.7575332866152769
# 选择feature_importance前65位,score is: 0.7687456201822004
# 选择feature_importance前66位,score is: 0.7631394533987386
# 选择feature_importance前67位,score is: 0.7638402242466713
# 选择feature_importance前68位,score is: 0.7652417659425368
# 选择feature_importance前69位,score is: 0.764540995094604
# 选择feature_importance前70位,score is: 0.759635599159075
# 选择feature_importance前71位,score is: 0.7666433076384023
# (0.7813594954449895, 8)

# %%
#经过上述迭代,选择前8列效果最好
useless=[]
i=8
for feature in x_train.columns:
    if feature in [t[1] for t in feature_importance[i:]]:
        useless.append(feature)
x_train.drop(useless,axis=1,inplace=True)
x_test.drop(useless,axis=1,inplace=True)
print(x_train.shape)
# Out:
# (3327, 8)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost.sklearn import XGBClassifier
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
import lightgbm as lgb
from sklearn.metrics import accuracy_score,f1_score,precision_score,recall_score,roc_auc_score,roc_curve

lr_model = LogisticRegression()
svm_model = svm.SVC(probability=True)
dt_model = DecisionTreeClassifier()
lgb_model=lgb.LGBMClassifier()
xgb_model = XGBClassifier()
knn_model=KNeighborsClassifier()
gbdt_model=GradientBoostingClassifier(n_estimators=100)
rf_model=RandomForestClassifier(n_estimators=100)


models={'LR':lr_model,'svm':svm_model,'knn':knn_model,'decision tree':dt_model,
        'xgboost':xgb_model,'gbt':gbdt_model,'random forest':rf_model,'lgb':lgb_model}

# %%
df_result=pd.DataFrame(columns=['model','accuracy','precision','recall','f1_score','roc_auc_score'])

# %%
#定义评价函数,根据y_pred和y_test返回acc,p,r和f1值
def evaluate(y_pred,y_test):
    acc=accuracy_score(y_test,y_pred)
    p=precision_score(y_test,y_pred)
    r=recall_score(y_test,y_pred)
    f1=f1_score(y_test,y_pred)

    return acc,p,r,f1

#进一步每个模型model进行迭代,并将df_result进行填充,并计算auc值
row=0  
for name,model in models.items():
    model.fit(x_train,y_train)
    y_pred=model.predict(x_test)
    y_pred_proba=model.predict_proba(x_test)[:,1]
    acc,p,r,f1=evaluate(y_pred,y_test)
    auc=roc_auc_score(y_test,y_pred_proba)
    df_result.loc[row]=[name,acc,p,r,f1,auc]
    row+=1
    
df_result
# Out:
# C:\Users\60547\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\60547\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
#            model  accuracy  precision    recall  f1_score  roc_auc_score
# 0             LR  0.770848   0.603896  0.259053  0.362573       0.744862
# 1            svm  0.775753   0.648855  0.236769  0.346939       0.708464
# 2            knn  0.740014   0.475000  0.317549  0.380634       0.677646
# 3  decision tree  0.691661   0.399504  0.448468  0.422572       0.610938
# 4        xgboost  0.784863   0.647727  0.317549  0.426168       0.751946
# 5            gbt  0.780659   0.617347  0.337047  0.436036       0.747182
# 6  random forest  0.775053   0.605556  0.303621  0.404453       0.742447
# 7            lgb  0.766643   0.559633  0.339833  0.422877       0.738918

# %% [markdown]
# 模型中最重要的指标为recall score何roc_auc_score，综合考量xgboost模型分类效果最好，用混淆矩阵进行可视化

# %%
from xgboost.sklearn import XGBClassifier
xgb=XGBClassifier()

# %%
#引入混淆矩阵对分类的结果进行可视化
from sklearn.metrics import confusion_matrix
import itertools
def plot_confusion_matrix(cm, classes,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=0)
    plt.yticks(tick_marks, classes)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
cnf_xgb=confusion_matrix(y_test,model_metrics(xgb,x_train,x_test,y_train,y_test)[1])
class_names=[0,1]
plot_confusion_matrix(cnf_xgb,class_names)
# Out:
# [准确率] 训练集： 0.8227 测试集： 0.7849
# [auc值] 训练集： 0.8597 测试集： 0.7519
# C:\Users\60547\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\60547\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %% [markdown]
# 特征工程总结:
# 选取模型随机森林
# 1#初步的业务角度丢弃了9列，保留81列特征列分析(包含标签列status)
# 2#IV值筛选,大于0.02的值作为有效预测列，筛选得到71列
# 3#随机森林模型feature importance筛选,按照排序保留了30列作为最后的特征分析列
# 4#引入多个模型进行训练计算，并返回其精度,查准率,查全率等
# 具体结果如图![image.png](attachment:image.png)
# #补充以下
# 特征工程还可关系热力图进行筛选,此处没有展示(代码屏蔽),
# 还有卡方检验方法,后续进行尝试
# 1#将各列和标签列status的相关性进行计算线性相关性
# 2#筛选小于corr<0.05即认定为对标签列无影响的列进行删除
# 3#剩下的特征列中进一步筛选，用关系型热力图两两比较，大于0.90的只保留一列
# 后续思考：上述模型中计算出来的recall均不高,决策树模型反而可以做到最高的查全率,但是查准率却很低,如果综合考虑的话应该是xgboost模型最好,样本不均衡还是选择AUC -score作为最终的分数
#
# 5-16更新:feature_importance前N列的选择,迭代后N=8，即根据feature importance前8列作为特征列,精度最高：为0.781，
# ![image.png](attachment:image.png)
#
# 发现选30列和8列做特征效果一样
